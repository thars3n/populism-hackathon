# %%
# Part 1 : gensim LDA based on NLTK & SpaCy

# Run in python console
import nltk; nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/ipekcinar/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# spacy for lemmatization
import spacy

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %%
# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# For Shakespeare : We need to change this: kill thou, thy and shall & keep subject, re, edu and use
stop_words.extend(['may', 'make', 'would', 'shall', 'must', 'could', 'applause'])  # make, come, go also very common

# %%
# Import Dataset -- original source
'''
df = pd.read_json('https://raw.githubusercontent.com/selva86/datasets/master/newsgroups.json')
print(df.target_names.unique())
df.head()

# Convert to list
data = df.content.values.tolist()

# Remove Emails
data = [re.sub('\S*@\S*\s?', '', sent) for sent in data]

# Remove new line characters
data = [re.sub('\s+', ' ', sent) for sent in data]

# Remove distracting single quotes
data = [re.sub("\'", "", sent) for sent in data]

pprint(data[:1])
'''
# Out:
# '\ndf = pd.read_json(\'https://raw.githubusercontent.com/selva86/datasets/master/newsgroups.json\')\nprint(df.target_names.unique())\ndf.head()\n\n# Convert to list\ndata = df.content.values.tolist()\n\n# Remove Emails\ndata = [re.sub(\'\\S*@\\S*\\s?\', \'\', sent) for sent in data]\n\n# Remove new line characters\ndata = [re.sub(\'\\s+\', \' \', sent) for sent in data]\n\n# Remove distracting single quotes\ndata = [re.sub("\'", "", sent) for sent in data]\n\npprint(data[:1])\n'

# %%
# Import Dataset -- Shakespeare

# Pull all into "data" = all Shakespeare raw text

# directory containing all source texts for training the model 
data_dir="/Users/ipekcinar/Desktop/populism-hackathon/corpus_populism/United States/2016/Bernie Sanders"
import glob, os
os.chdir(data_dir)

#documents = list()
data = list()   # reset data to 0

for filename in glob.glob("*.txt"):
    filedata = open(filename, 'r').read()
    print(filename + " = " + str(len(filedata)) + " chars")
    #documents = documents + filedata.split(".")
    data.append(filedata)
# Out:
# Clinton102416.txt = 23434 chars
# Sanders111915.txt = 39871 chars
# Clinton110416.txt = 21670 chars
# Trump100516.txt = 12214 chars
# Trump102116.txt = 9767 chars
# Sanders012616.txt = 26810 chars
# Trump110116.txt = 13623 chars
# Trump090716.txt = 14165 chars
# Clinton100216.txt = 10528 chars
# Trump081816.txt = 18203 chars
# Trump102916_2.txt = 4771 chars
# Clinton091916.txt = 20921 chars
# Trump102316.txt = 10637 chars
# Trump061316.txt = 17787 chars
# Sanders041516.txt = 10767 chars
# Sanders020116.txt = 7692 chars
# Clinton102616.txt = 16458 chars
# Sanders032116.txt = 21519 chars
# Trump080516.txt = 50632 chars
# Trump100316.txt = 6179 chars
# Sanders091915.txt = 9123 chars
# Clinton102216.txt = 23948 chars
# Trump110716.txt = 34499 chars
# Trump090116.txt = 7175 chars
# Sanders030116.txt = 5662 chars
# Trump102716.txt = 22285 chars
# Clinton092916.txt = 22017 chars
# Clinton060216.txt = 23848 chars
# Clinton110716_2.txt = 20952 chars
# Clinton101116.txt = 15686 chars
# Clinton093016_2.txt = 16626 chars
# Trump091616.txt = 9241 chars
# Trump091216_2.txt = 9508 chars
# Trump081216.txt = 42433 chars
# Trump102916.txt = 12345 chars
# Trump093016.txt = 14561 chars
# Clinton052015.txt = 10175 chars
# Sanders052615.txt = 19612 chars
# Trump092916.txt = 10832 chars
# Trump091416.txt = 9989 chars
# Sanders020916.txt = 12533 chars
# Trump080916.txt = 39871 chars
# Trump100316_2.txt = 17570 chars
# Trump101316_2.txt = 9659 chars
# Trump083016.txt = 11357 chars
# Clinton103116_2.txt = 20230 chars
# Trump042716.txt = 27348 chars
# Clinton092816.txt = 12341 chars
# Sanders081515.txt = 9322 chars
# Trump090916.txt = 15235 chars
# Sanders072516.txt = 11541 chars
# Sanders082815.txt = 6617 chars
# Trump062216.txt = 19951 chars
# Trump101216.txt = 46805 chars
# Clinton051915.txt = 6619 chars
# Clinton091516.txt = 15001 chars
# Sanders042616.txt = 31791 chars
# Trump081616.txt = 16838 chars
# Clinton103116.txt = 16158 chars
# Trump091316_2.txt = 10718 chars
# Trump091216.txt = 10621 chars
# Sanders072515.txt = 33144 chars

# %%
# %%time

def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

print(data_words[:1])
print('\n')
# Out:
# [[u'thank', u'you', u'wow', u'well', u'don', u'know', u'about', u'you', u'but', u'could', u'listen', u'to', u'elizabeth', u'warren', u'go', u'on', u'all', u'day', u'it', u'is', u'so', u'great', u'to', u'be', u'back', u'here', u'in', u'new', u'hampshire', u'have', u'significant', u'unruly', u'group', u'of', u'women', u'went', u'to', u'wellesley', u'with', u'back', u'here', u'oh', u'it', u'is', u'so', u'wonderful', u'to', u'be', u'here', u'on', u'this', u'college', u'campus', u'and', u'to', u'see', u'so', u'many', u'young', u'people', u'here', u'as', u'maggie', u'and', u'elizabeth', u'and', u'were', u'walking', u'up', u'to', u'the', u'stage', u'and', u'lot', u'of', u'people', u'were', u'hanging', u'out', u'of', u'the', u'windows', u'and', u'we', u're', u'glad', u'that', u'you', u've', u'got', u'the', u'best', u'view', u'of', u'what', u'we', u're', u'doing', u'here', u'it', u'also', u'exciting', u'to', u'be', u'here', u'with', u'two', u'weeks', u'left', u'because', u'this', u'is', u'the', u'most', u'consequential', u'election', u'of', u'our', u'lifetime', u'and', u'to', u'see', u'the', u'energy', u'and', u'enthusiasm', u'that', u'this', u'crowd', u'displayed', u'saw', u'it', u'yesterday', u'in', u'north', u'carolina', u'saw', u'it', u'the', u'day', u'before', u'in', u'ohio', u'it', u'really', u'does', u'demonstrate', u'that', u'americans', u'are', u'really', u'looking', u'at', u'what', u'at', u'stake', u'and', u'are', u'coming', u'to', u'the', u'conclusion', u'that', u'we', u'all', u'have', u'to', u'be', u'involved', u'in', u'the', u'remaining', u'days', u'of', u'the', u'campaign', u'and', u'that', u'everyone', u'needs', u'to', u'turn', u'out', u'to', u'vote', u'in', u'new', u'hampshire', u'you', u'have', u'lot', u'of', u'reasons', u'to', u'vote', u'you', u've', u'got', u'great', u'candidates', u'for', u'congress', u'annie', u'kuster', u'and', u'carol', u'shea', u'porter', u'who', u'deserve', u'your', u'support', u'and', u'you', u've', u'got', u'great', u'candidate', u'for', u'governor', u'colin', u'van', u'ostern', u'thank', u'you', u'know', u'that', u'maggie', u'and', u'elizabeth', u'and', u'have', u'been', u'out', u'here', u'giving', u'the', u'full', u'dose', u'but', u'hope', u'that', u'you', u'will', u'know', u'what', u'is', u'at', u'stake', u'in', u'the', u'governor', u'race', u'and', u'in', u'sending', u'these', u'two', u'extraordinary', u'women', u'to', u'the', u'house', u'and', u'boy', u'it', u'is', u'exciting', u'to', u'be', u'here', u'with', u'maggie', u'and', u'elizabeth', u'because', u'they', u'are', u'people', u'who', u'fight', u'for', u'you', u'every', u'single', u'day', u'know', u'these', u'women', u'and', u'it', u'is', u'privilege', u'to', u'be', u'on', u'this', u'stage', u'with', u'them', u'now', u'elizabeth', u'warren', u'has', u'track', u'record', u'of', u'making', u'it', u'her', u'mission', u'to', u'stand', u'up', u'against', u'wall', u'street', u'and', u'she', u'is', u'going', u'to', u'make', u'sure', u'that', u'wall', u'street', u'never', u'wrecks', u'main', u'street', u'again', u'but', u'you', u'may', u'not', u'know', u'that', u'she', u'was', u'the', u'person', u'behind', u'setting', u'up', u'the', u'agency', u'that', u'protects', u'consumers', u'the', u'consumer', u'financial', u'protection', u'bureau', u'and', u'it', u'was', u'set', u'up', u'to', u'stand', u'against', u'and', u'to', u'do', u'something', u'about', u'the', u'kinds', u'of', u'fraud', u'and', u'abuse', u'we', u've', u'seen', u'from', u'wells', u'fargo', u'and', u'they', u'are', u'on', u'the', u'front', u'lines', u'of', u'returning', u'billions', u'of', u'dollars', u'to', u'americans', u'who', u'have', u'been', u'cheated', u'and', u'defrauded', u'by', u'big', u'companies', u'by', u'banks', u'and', u'others', u'in', u'fact', u'think', u'it', u'is', u'fair', u'to', u'say', u'some', u'of', u'the', u'best', u'tv', u'that', u'you', u'can', u'see', u'is', u'on', u'span', u'when', u'elizabeth', u'is', u'going', u'after', u'bank', u'executive', u'or', ...
#
#
# CPU times: user 2.08 s, sys: 57.2 ms, total: 2.13 s
# Wall time: 2.1 s

# %%
#%%time

# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# See trigram example
print(trigram_mod[bigram_mod[data_words[0]]])
print('\n')
# Out:
'fraud', u'and', u'abuse', u'we', u've', u'seen', u'from', u'wells_fargo', u'and', u'they', u'are', u'on', u'the', u'front_lines', u'of', u'returning', u'billions', u'of', u'dollars', u'to', u'americans', u'who', u'have', u'been', u'cheated', u'and', u'defrauded', u'by', u'big', u'companies', u'by', u'banks', u'and', u'others', u'in', u'fact', u'think', u'it', u'is', u'fair', u'to', u'say', u'some', u'of', u'the', u'best', u'tv', u'that', u'you', u'can', u'see', u'is', u'on', u'span', u'when', u'elizabeth', u'is', u'going', u'after', u'bank', u'executive', u'or', u'regulator', u'she', u'is', u'r ...

# %%
# Define functions for stopwords, bigrams, trigrams and lemmatization
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
# %%time
# This cell takes 2-3 minutes to run on my machine.  -j

# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# python3 -m spacy download en
nlp = spacy.load('en', disable=['parser', 'ner'])

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

print(data_lemmatized[:1])
print('\n')
# Out:
# [[u'thank', u'know', u'listen', u'elizabeth', u'go', u'day', u'great', u'back', u'new_hampshire', u'significant', u'unruly', u'group', u'woman', u'go', u'wellesley', u'back', u'wonderful', u'college', u'campus', u'see', u'many', u'young', u'people', u'maggie', u'elizabeth', u'walking', u'stage', u'lot', u'people', u'hang', u'window', u'glad', u'get', u'good', u'view', u'also', u'excite', u'week', u'leave', u'consequential', u'election', u'lifetime', u'see', u'energy', u'enthusiasm', u'crowd', u'display', u'see', u'yesterday', u'north_carolina', u'see', u'day', u'ohio', u'really', u'demonstrate', u'american', u'really', u'look', u'stake', u'come', u'conclusion', u'involve', u'remain', u'day', u'campaign', u'everyone', u'need', u'turn', u'vote', u'new_hampshire', u'lot', u'reason', u'vote', u'get', u'great', u'candidate', u'congress', u'annie', u'kuster', u'carol', u'shea', u'porter', u'deserve', u'support', u'get', u'great', u'candidate', u'governor', u'colin', u'van', u'ostern', u'thank', u'know', u'maggie', u'elizabeth', u'give', u'full', u'dose', u'hope', u'know', u'stake', u'governor', u'race', u'send', u'extraordinary', u'woman', u'house', u'boy', u'exciting', u'maggie', u'elizabeth', u'people', u'fight', u'single', u'day', u'know', u'woman', u'privilege', u'stage', u'elizabeth', u'track', u'record', u'make', u'mission', u'stand', u'wall_street', u'go', u'sure', u'wall_street', u'never', u'wreck', u'main', u'street', u'know', u'person', u'set', u'agency', u'protect', u'consumer', u'consumer', u'financial', u'protection', u'bureau', u'set', u'stand', u'something', u'kind', u'fraud', u'abuse', u'see', u'wells_fargo', u'front_line', u'return', u'billion', u'dollar', u'american', u'cheat', u'defraud', u'big', u'company', u'bank', u'other', u'fact', u'think', u'fair', u'say', u'good', u'tv', u'see', u'span', u'elizabeth', u'go', u'bank', u'executive', u'regulator', u'refuse', u'refuse', u'let', u'hook', u'speak', u'speak', u'single', u'american', u'frustrated', u'feed', u'looking_forward', u'work', u'rewrite', u'rule', u'economy', u'sure', u'grow', u'fair', u'single', u'person', u'work', u'hard', u'america', u'know', u'phone', u'can', u'not', u'check', u'tweet', u'kind', u'expect', u'hear', u'say', u'tweet', u'away', u'get', u'thin', u'skin', u'nobody', u'else', u'call', u'mysterious', u'tax_return', u'expose', u'temperamentally_unfit', u'totally', u'unqualified', u'president', u'united_state', u'maggie', u'go', u'great', u'united_state', u'senator', u'new_hampshire', u'take', u'word', u'elizabeth', u'word', u'look', u'already', u'do', u'maggie', u'leadership', u'new_hampshire', u'low', u'unemployment_rate', u'entire', u'country', u'governorship', u'rank', u'good', u'state', u'country', u'business', u'do', u'new_hampshire', u'way', u'bring', u'people', u'together', u'democrat', u'republican', u'independent', u'think', u'big', u'legislature', u'probably', u'world', u'deal', u'really', u'hone', u'skill', u'listen', u'try', u'work', u'people', u'take', u'issue', u'keep', u'family', u'night', u'sky', u'rocket', u'cost', u'college', u'prescription_drug', u'help', u'student', u'figure', u'way', u'afford', u'get', u'education', u'help', u'suffer', u'addiction', u'mental_health', u'raise', u'wage', u'hard', u'work', u'family', u'love', u'maggie', u'independent', u'know', u'find', u'common_ground', u'stand', u'ground', u'exactly', u'kind', u'leader', u'need', u'united_state', u'senate', u'get', u'break', u'gridlock', u'dysfunction', u'unfortunately', u'mar', u'washington', u'get', u'back', u'listen', u'respectfully', u'disagree', u'disagreeable', u'need', u'leader', u'maggie', u'opponent', u'never', u'afraid', u'stand', u'donald_trump', u'know', u'role', u'model', u'kid', u'anybody', u'else', u'matter', u'hope', u'next', u'day', u'everything', u'support', u'want', u'say', u'word', u'colin', u'also', u'know', u'number', u'year', u'maggie', u'leave', u'big', u'shoe', u'look', u'leave', u'big', u'shoe', u'fill', u'governor', u'colin', u'pe ...
#
#
# CPU times: user 20.2 s, sys: 636 ms, total: 20.8 s
# Wall time: 13.4 s

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# View
print(corpus[:1])
# Out:
# [[(0, 2), (1, 1), (2, 1), (3, 2), (4, 1), (5, 6), (6, 1), (7, 1), (8, 2), (9, 1), (10, 2), (11, 2), (12, 3), (13, 1), (14, 1), (15, 3), (16, 2), (17, 2), (18, 3), (19, 14), (20, 9), (21, 3), (22, 1), (23, 4), (24, 1), (25, 1), (26, 2), (27, 1), (28, 3), (29, 2), (30, 1), (31, 2), (32, 3), (33, 10), (34, 2), (35, 1), (36, 1), (37
291, 4), (292, 1), (293, 1), (294, 1), (295, 1), (296, 1), (297, 3), (298, 2), (299, 1), (300, 1), (301, 1), (302, 5), (303, 3), (304, 1), (305, 1), (306, 1), (307, 1), (308, 2), (309, 1), (310, 1), (311, 3), (312, 1), (313, 1), (314, 1), (315, 2), (316, 2), (317, 1), (318, 9), (319, 3), (320, 1), (321, 7), (322, 1), (323, 4), (324, 23), (325, 1), (326, 1), (327, 2), (328, 1), (329, 1), (330, 1), (331, 2), (332, 3), (333, 1), (334, 1), (335, 1), (336, 5), (337, 1), (338, 1), (339, 1), (340, 1), (341, 2), (342, 4), (343, 1), (344, 1), (345, 1), (346, 1), (347, 2), (348, 4), (349, 4), (350, 1), (351, 2), (352, 2), (353, 5), (354, 1), (355, 1), (356, 4), (357, 11), (358, 1), (359, 1), (360, 3), (361, 1), (362, 1), (363, 11), (364, 2), (365, 2), (366, 1), (367, 7), (368, 2), (369, 1), (370, 6), (371, 1), (372, 1), (373, 1), (374, 3), (375, 2), (376, 3), (377, 1), (378, 1), (379, 1), (380, 1), (381, 1), (382, 2), (383, 1), (384, 1), (385, 1), (386, 2), (387, 1), (388, 1), (389, 1), (390, 1), (391, 1), (392, 1), (393, 1), (394, 1), (395, 1), (396, 1), (397, 4), (398, 1), (399, 3), (400, 8), (401, 5), (402, 7), (403, 17), (404, 1), (405, 3), (406, 1), (407, 2), (408, 2), (4 ...

# %%
id2word[0]
# Out:
# u'able'

# %%
# Human readable format of corpus (term-frequency)
[[(id2word[id], freq) for id, freq in cp] for cp in corpus[:1]]
# Out:
# [[(u'able', 2),
#   (u'absolutely', 1),
#   (u'abuse', 1),
#   (u'achieve', 2),
#   (u'action', 1),
#   (u'actually', 6),
#   (u'ad', 1),
#   (u'add', 1),
#   (u'addiction', 2),
#   (u'addition', 1),
#   (u'advanced_manufactur', 2),
#   (u'afford', 2),
#   (u'affordable', 3),
#   (u'afraid', 1),
#   (u'agency', 1),
#   (u'ahead', 3),
#   (u'ally', 2),
#   (u'already', 2),
#   (u'also', 3),
#   (u'america', 14),
#   (u'american', 9),
#   (u'annie', 3),
#   (u'anti', 1),
#   (u'anybody', 4),
#   (u'anymore', 1),
#   (u'anyone', 1),
#   (u'anything', 2),
#   (u'anywhere', 1),
#   (u'ask', 3),
#   (u'attack', 2),
#   (u'attention', 1),
#   (u'away', 2),
#   (u'baby', 3),
#   (u'back', 10),
#   (u'bad', 2),
#   (u'balance', 1),
#   (u'ball', 1),
#   (u'ballot', 1),
#   (u'bank', 4),
#   (u'barrier', 1),
#   (u'basically', 1),
#   (u'battle', 1),
#   (u'beautiful', 1),
#   (u'become', 1),
#   (u'behalf', 1),
#   (u'believe', 6),
#   (u'bernie', 1),
#   (u'bernie_sander', 1),
#   (u'big', 8),
#   (u'biggest_investment', 1),
#   (u'billion', 1),
#   (u'billion_dollar', 3),
#   (u'billionair', 1),
#   (u'bit', 1),
#   (u'book', 1),
#   (u'boy', 1),
#   (u'break', 2),
#   (u'bring', 2),
#   (u'budget', 1),
#   (u'bureau', 2),
#   (u'business', 2),
#   (u'calculator', 1),
#   (u'call', 5),
#   (u'campaign', 8),
#   (u'campus', 1),
#   (u'can', 2),
#   (u'candidate', 2),
#   (u'care', 2),
#   (u'carol', 3),
#   (u'case', 1),
#   (u'casino', 1),
#   (u'chance', 2),
#   (u'change', 1),
#   (u'cheat', 1),
#   (u'check', 1),
#   (u'chief', 1),
#   (u'child', 2),
#   (u'childcare', 1),
#   (u'choice', 1),
#   (u'city', 1),
#   (u'clean_energy', 4),
#   (u'clear', 3),
#   (u'climb', 1),
#   (u'clinton', 1),
#   (u'close', 1),
#   (u'club', 2),
#   (u'co', 1),
#   (u'colin', 5),
#   (u'college', 6),
#   (u'come', 14),
#   (u'commander', 1),
#   (u'common', 1),
#   (u'common_ground', 1),
#   (u'community', 2),
#   (u'company', 1),
#   (u'compete', 5),
#   (u'competition', 1),
#   (u'conclusion', 1),
#   (u'confident', 1),
#   (u'confirm', 1),
#   (u'congress', 1),
#   (u'consequential', 1),
#   (u'consumer', 3),
#   (u'contract', 1),
#   (u'contractor', 1),
#   (u'contrast', 1),
#   (u'convenient', 1),
#   (u'copy', 2),
#   (u'corporation', 1),
#   (u'cost', 3),
#   (u'council', 1),
#   (u'count', 1),
#   (u'country', 17),
#   (u'course', 3),
#   (u'create', 2),
#   (u'criticize', 2),
#   (u'cross', 2),
#   (u'crowd', 1),
#   (u'cynicism', 1),
#   (u'dad', 1),
#   (u'dangerous', 1),
#   (u'daughter', 2),
#   (u'day', 11),
#   (u'deal', 1),
#   (u'debate', 4),
#   (u'debt', 5),
#   (u'decade', 1),
#   (u'decision', 1),
#   (u'declare', 1),
#   (u'deeply', 1),
#   (u'defeat', 2),
#   (u'defraud', 1),
#   (u'deliver', 1),
#   (u'democracy', 3),
#   (u'democrat', 2),
#   (u'demonstrate', 1),
#   (u'denigrate', 1),
#   (u'deploy', 1),
#   (u'deserve', 1),
#   (u'die', 1),
#   (u'difficult', 1),
#   (u'dignity', 1),
#   (u'direct', 2),
#   (u'disagree', 1),
#   (u'disagreeable', 1),
#   (u'disagreement', 1),
#   (u'discouraged', 1),
#   (u'discrimination', 1),
#   (u'disorder', 1),
#   (u'display', 1),
#   (u'disturb', 1),
#   (u'divide', 2),
#   (u'division', 1),
#   (u'do', 6),
#   (u'dollar', 1),
#   (u'donald', 3),
#   (u'donald_trump', 8),
#   (u'door', 1),
#   (u'dose', 1),
#   (u'doubt', 1),
#   (u'drug', 1),
#   (u'dumb', 1),
#   (u'dysfunction', 1),
#   (u'early', 3),
#   (u'easier', 1),
#   (u'economic', 2),
#   (u'economy', 6),
#   (u'edge', 1),
#   (u'education', 5),
#   (u'educator', 1),
#   (u'effort', 1),
#   (u'election', 10),
#   (u'eliminate', 1),
#   (u'elizabeth', 11),
#   (u'else', 6),
#   (u'empower', 1),
#   (u'end', 4),
#   (u'energy', 3),
#   (u'enforce', 1),
#   (u'enough', 2),
#   (u'enthusiasm', 1),
#   (u'entire', 1),
#   (u'environment', 1),
#   (u'epidemic', 1),
#   (u'especially', 1),
#   (u'even', 2),
#   (u'ever', 1),
#   (u'everybody', 3),
#   (u'everyday', 2),
#   (u'everyone', 3),
#   (u'everything', 5),
#   (u'exactly', 1),
#   (u'example', 1),
#   (u'excite', 1),
#   (u'excited', 1),
#   (u'exciting', 3),
#   (u'executive', 2),
#   (u'exile', 1),
#   (u'expand', 1),
#   (u'expect', 1),
#   (u'explanation', 1),
#   (u'export', 1),
#   (u'exporter', 1),
#   (u'expose', 1),
#   (u'extraordinary', 1),
#   (u'face', 2),
#   (u'fact', 3),
#   (u'fail', 1),
#   (u'failure', 1),
#   (u'fair', 3),
#   (u'fair_share', 1),
#   (u'faith', 1),
#   (u'familiar', 1),
#   (u'family', 14),
#   (u'far', 1),
#   (u'feed', 1),
#   (u'fight', 5),
#   (u'fighting', 1),
#   (u'figure', 1),
#   (u'fill', 1),
#   (u'finally', 2),
#   (u'financial', 2),
#   (u'find', 1),
#   (u'fine', 2),
#   (u'fire', 3),
#   (u'first', 3),
#   (u'first_lady', 1),
#   (u'focused', 1),
#   (u'foreign_policy', 1),
#   (u'forward', 1),
#   (u'fraud', 1),
#   (u'free', 2),
#   (u'friend', 2),
#   (u'front_line', 1),
#   (u'frustrate', 1),
#   (u'frustrated', 1),
#   (u'full', 6),
#   (u'fundamental', 1),
#   (u'funding', 1),
#   (u'future', 5),
#   (u'gay', 2),
#   (u'general', 1),
#   (u'germany', 2),
#   (u'get', 30),
#   (u'girl', 1),
#   (u'give', 5),
#   (u'glad', 2),
#   (u'glee', 1),
#   (u'go', 46),
#   (u'goal', 1),
#   (u'gold_star', 1),
#   (u'golf', 4),
#   (u'good', 10),
#   (u'governor', 3),
#   (u'governorship', 1),
#   (u'grandkid', 1),
#   (u'grant', 1),
#   (u'great', 8),
#   (u'gridlock', 1),
#   (u'grieve', 1),
#   (u'ground', 1),
#   (u'group', 1),
#   (u'grow', 3),
#   (u'guarantee_equal', 1),
#   (u'guess', 1),
#   (u'gut', 1),
#   (u'guy', 1),
#   (u'half_hour', 1),
#   (u'hand', 1),
#   (u'hang', 1),
#   (u'happen', 3),
#   (u'harass', 1),
#   (u'harassment', 1),
#   (u'hard', 5),
#   (u'hate', 2),
#   (u'head', 1),
#   (u'heal', 1),
#   (u'health', 2),
#   (u'health_care', 1),
#   (u'hear', 3),
#   (u'heart', 2),
#   (u'help', 10),
#   (u'high', 4),
#   (u'high_school', 1),
#   (u'historic', 1),
#   (u'hold', 2),
#   (u'home', 1),
#   (u'hone', 1),
#   (u'honor', 2),
#   (u'hook', 2),
#   (u'hop', 1),
#   (u'hope', 4),
#   (u'horrifying', 1),
#   (u'hospital', 1),
#   (u'house', 1),
#   (u'human', 1),
#   (u'husband', 1),
#   (u'idea', 3),
#   (u'imagine', 2),
#   (u'important', 1),
#   (u'impose', 1),
#   (u'include', 1),
#   (u'income', 5),
#   (u'independent', 3),
#   (u'infrastructure', 1),
#   (u'innovation', 1),
#   (u'instead', 1),
#   (u'institution', 1),
#   (u'insult', 2),
#   (u'intelligence', 1),
#   (u'interested', 1),
#   (u'invest', 3),
#   (u'investment', 1),
#   (u'involve', 1),
#   (u'iraq', 1),
#   (u'isis', 2),
#   (u'issue', 2),
#   (u'jail', 1),
#   (u'job', 9),
#   (u'keep', 3),
#   (u'key', 1),
#   (u'kid', 7),
#   (u'kill', 1),
#   (u'kind', 4),
#   (u'know', 23),
#   (u'kuster', 1),
#   (u'ladder', 1),
#   (u'last', 2),
#   (u'last_night', 1),
#   (u'laugh', 1),
#   (u'law', 1),
#   (u'lead', 2),
#   (u'leader', 3),
#   (u'leadership', 1),
#   (u'learn', 1),
#   (u'least', 1),
#   (u'leave', 5),
#   (u'left_behind', 1),
#   (u'legislature', 1),
#   (u'less', 1),
#   (u'lesson', 1),
#   (u'let', 2),
#   (u'level', 4),
#   (u'lgbt', 1),
#   (u'lie', 1),
#   (u'life', 1),
#   (u'lifetime', 1),
#   (u'line', 2),
#   (u'list', 4),
#   (u'listen', 4),
#   (u'little', 1),
#   (u'live', 2),
#   (u'long', 2),
#   (u'look', 5),
#   (u'looking_forward', 1),
#   (u'loophole', 1),
#   (u'lose', 4),
#   (u'lot', 11),
#   (u'love', 1),
#   (u'love_trump', 1),
#   (u'low', 3),
#   (u'low_wage', 1),
#   (u'machining', 1),
#   (u'maggie', 11),
#   (u'main', 2),
#   (u'maintenance', 2),
#   (u'major', 1),
#   (u'make', 7),
#   (u'man', 2),
#   (u'manufacture', 1),
#   (u'many', 6),
#   (u'mar', 1),
#   (u'marriage_equality', 1),
#   (u'mass', 1),
#   (u'matter', 3),
#   (u'maybe', 2),
#   (u'mean', 3),
#   (u'medicaid', 1),
#   (u'meet', 1),
#   (u'member', 1),
#   (u'mental_health', 1),
#   (u'michelle_obama', 1),
#   (u'middle_class', 2),
#   (u'milestone', 1),
#   (u'military', 1),
#   (u'million', 1),
#   (u'millionaire', 2),
#   (u'minimum_wage', 1),
#   (u'mission', 1),
#   (u'mock', 1),
#   (u'model', 1),
#   (u'mom', 1),
#   (u'moment', 1),
#   (u'moratorium', 1),
#   (u'mosul', 1),
#   (u'motivate', 1),
#   (u'motivated', 1),
#   (u'much', 4),
#   (u'mysterious', 1),
#   (u'national', 3),
#   (u'need', 8),
#   (u'never', 5),
#   (u'new', 7),
#   (u'new_hampshire', 17),
#   (u'new_york', 1),
#   (u'next', 3),
#   (u'night', 1),
#   (u'nobody', 2),
#   (u'north_carolina', 2),
#   (u'not', 2),
#   (u'nothing', 1),
#   (u'novel', 1),
#   (u'november', 1),
#   (u'november_th', 2),
#   (u'number', 3),
#   (u'nurse', 1),
#   (u'obama', 2),
#   (u'office', 1),
#   (u'ohio', 1),
#   (u'old', 1),
#   (u'old_fashioned', 1),
#   (u'one', 1),
#   (u'opponent', 4),
#   (u'opportunity', 2),
#   (u'optimistic', 1),
#   (u'ostern', 1),
#   (u'other', 1),
#   (u'ought', 1),
#   (u'overflow', 1),
#   (u'owner', 1),
#   (u'painful', 2),
#   (u'parent', 2),
#   (u'part', 2),
#   (u'partner', 1),
#   (u'party', 2),
#   (u'pass', 1),
#   (u'pay', 13),
#   (u'peace', 1),
#   (u'peaceful', 1),
#   (u'pell_grant', 1),
#   (u'penny', 2),
#   (u'people', 18),
#   (u'percent', 2),
#   (u'percentage', 1),
#   (u'perfect', 1),
#   (u'person', 8),
#   (u'phone', 2),
#   (u'pittsburgh', 1),
#   (u'place', 2),
#   (u'plan', 8),
#   (u'planned_parenthood', 1),
#   (u'please', 1),
#   (u'police', 1),
#   (u'police_officer', 1),
#   (u'political', 1),
#   (u'politically', 1),
#   (u'polling', 1),
#   (u'ponder', 2),
#   (u'pop', 1),
#   (u'port', 1),
#   (u'porter', 1),
#   (u'pose', 2),
#   (u'positive', 1),
#   (u'poverty', 1),
#   (u'power', 2),
#   (u'precision', 1),
#   (u'pregnancy', 1),
#   (u'prepare', 2),
#   (u'prescription', 1),
#   (u'prescription_drug', 1),
#   (u'president', 13),
#   (u'primary', 1),
#   (u'printing', 1),
#   (u'privilege', 1),
#   (u'probably', 1),
#   (u'problem', 2),
#   (u'product', 2),
#   (u'promise', 1),
#   (u'propose', 2),
#   (u'prosperity', 1),
#   (u'protect', 3),
#   (u'protection', 2),
#   (u'proud', 4),
#   (u'prove', 3),
#   (u'provide', 2),
#   (u'public_college', 1),
#   (u'push', 1),
#   (u'put', 4),
#   (u'quote', 2),
#   (u'race', 1),
#   (u'raise', 2),
#   (u'rally', 1),
#   (u'rank', 1),
#   (u'rate', 1),
#   (u'reach', 2),
#   (u'reagan', 1),
#   (u'really', 13),
#   (u'reason', 4),
#   (u'record', 1),
#   (u'refuse', 3),
#   (u'register', 3),
#   (u'regulator', 1),
#   (u'reject', 1),
#   (u'remain', 1),
#   (u'remember', 2),
#   (u'reminder', 1),
#   (u'report', 1),
#   (u'republican', 3),
#   (u'repudiate', 1),
#   (u'research', 1),
#   (u'respect', 2),
#   (u'respectfully', 1),
#   (u'result', 2),
#   (u'return', 1),
#   (u'reward', 1),
#   (u'rewrite', 1),
#   (u'rig', 1),
#   (u'right', 6),
#   (u'rise', 1),
#   (u'risk', 1),
#   (u'roads_bridge', 1),
#   (u'rock', 1),
#   (u'rocket', 1),
#   (u'role', 1),
#   (u'room', 1),
#   (u'root', 1),
#   (u'rule', 2),
#   (u'run', 5),
#   (u'running_casino', 1),
#   (u'safe', 1),
#   (u'safety', 1),
#   (u'save', 2),
#   (u'say', 19),
#   (u'scared', 1),
#   (u'school', 3),
#   (u'secretary', 2),
#   (u'see', 16),
#   (u'senate', 2),
#   (u'senator', 1),
#   (u'send', 4),
#   (u'seriously', 3),
#   (u'set', 2),
#   (u'shake', 1),
#   (u'shea', 1),
#   (u'shoe', 2),
#   (u'show', 2),
#   (u'shut', 1),
#   (u'side', 1),
#   (u'sign', 1),
#   (u'significant', 1),
#   (u'single', 4),
#   (u'skeptic', 1),
#   (u'skill', 3),
#   (u'skin', 1),
#   (u'sky', 1),
#   (u'slur', 1),
#   (u'small_business', 5),
#   (u'smart', 2),
#   (u'solar', 1),
#   (u'solar_panel', 1),
#   (u'solution', 1),
#   (u'someone', 2),
#   (u'something', 6),
#   (u'sometimes', 2),
#   (u'son', 2),
#   (u'sound', 1),
#   (u'span', 1),
#   (u'speak', 2),
#   (u'spend', 1),
#   (u'spring', 1),
#   (u'st_century', 1),
#   (u'stage', 2),
#   (u'stake', 3),
#   (u'stamina', 1),
#   (u'stand', 9),
#   (u'start', 8),
#   (u'starter', 1),
#   (u'state', 5),
#   (u'stator', 1),
#   (u'stay', 1),
#   (u'step', 1),
#   (u'stepping', 1),
#   (u'steroid', 1),
#   (u'stiff', 1),
#   (u'still', 2),
#   (u'stir', 1),
#   (u'stop', 1),
#   (u'story', 3),
#   (u'strain', 1),
#   (u'street', 1),
#   (u'strength', 1),
#   (u'stress', 1),
#   (u'striving', 1),
#   (u'strong', 1),
#   (u'student', 3),
#   (u'student_debt', 1),
#   (u'substance_abuse', 1),
#   (u'succeed', 1),
#   (u'suffer', 1),
#   (u'superpower', 1),
#   (u'supervisor', 1),
#   (u'support', 5),
#   (u'suppose', 1),
#   (u'sure', 5),
#   (u'surplus', 1),
#   (u'surprise', 1),
#   (u'take', 11),
#   (u'taken_advantage', 1),
#   (u'talent', 1),
#   (u'talk', 6),
#   (u'tax', 3),
#   (u'tax_cut', 1),
#   (u'tax_return', 1),
#   (u'teacher', 3),
#   (u'technical_education', 1),
#   (u'technology', 1),
#   (u'tell', 9),
#   (u'temperamentally_unfit', 1),
#   (u'terrorist', 1),
#   (u'text_join', 1),
#   (u'thank', 3),
#   (u'thin', 1),
#   (u'thing', 3),
#   (u'think', 16),
#   (u'thinking', 1),
#   (u'threat', 2),
#   (u'thrive', 2),
#   (u'throw', 1),
#   (u'tim', 3),
#   (u'tim_kaine', 1),
#   (u'time', 10),
#   (u'today', 3),
#   (u'together', 8),
#   (u'tonight', 1),
#   (u'top', 2),
#   (u'tormentor', 1),
#   (u'total_disaster', 1),
#   (u'totally', 1),
#   (u'tough', 1),
#   (u'track', 1),
#   (u'transfer', 1),
#   (u'transit', 1),
#   (u'treat', 1),
#   (u'trickle', 2),
#   (u'trillion', 2),
#   (u'troubling', 1),
#   (u'truly', 1),
#   (u'trump', 2),
#   (u'try', 6),
#   (u'tunnel', 1),
#   (u'turn', 3),
#   (u'tv', 1),
#   (u'tweet', 3),
#   (u'two_third', 1),
#   (u'underway', 1),
#   (u'unemployment_rate', 1),
#   (u'unfortunately', 1),
#   (u'unifying', 1),
#   (u'unite', 1),
#   (u'united_state', 3),
#   (u'universities_tuition', 1),
#   (u'unprecedented', 1),
#   (u'unqualified', 2),
#   (u'unruly', 1),
#   (u'upgrade', 1),
#   (u'use', 2),
#   (u'value', 1),
#   (u'van', 1),
#   (u'veteran', 1),
#   (u'vice', 1),
#   (u'victim', 1),
#   (u'view', 1),
#   (u'violence', 1),
#   (u'volunteer', 2),
#   (u'vote', 12),
#   (u'wage', 2),
#   (u'wake', 1),
#   (u'walking', 1),
#   (u'wall_street', 3),
#   (u'want', 25),
#   (u'washington', 1),
#   (u'water_system', 1),
#   (u'way', 6),
#   (u'wealthy', 2),
#   (u'week', 5),
#   (u'well', 4),
#   (u'wellesley', 1),
#   (u'wells_fargo', 1),
#   (u'whose', 1),
#   (u'willing', 1),
#   (u'win', 2),
#   (u'wind', 1),
#   (u'window', 1),
#   (u'wipe', 1),
#   (u'woman', 10),
#   (u'wonderful', 3),
#   (u'word', 4),
#   (u'work', 27),
#   (u'worker', 4),
#   (u'world', 5),
#   (u'wound', 1),
#   (u'wreck', 1),
#   (u'wrench', 1),
#   (u'write', 2),
#   (u'wrong', 1),
#   (u'year', 11),
#   (u'yesterday', 2),
#   (u'yet', 1),
#   (u'young', 6)]]

# %%
# %%time

### Much as we saw with Word2vec, these settings are the key to tuning your LDA Topic Model. ###

# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=3, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)
# Out:
# CPU times: user 9.79 s, sys: 68.5 ms, total: 9.86 s
# Wall time: 5.27 s

# %%
# Print the Keyword in the 10 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   u'0.022*"american" + 0.014*"country" + 0.014*"go" + 0.012*"job" + 0.011*"people" + 0.009*"america" + 0.006*"new" + 0.006*"year" + 0.006*"time" + 0.005*"want"'),
#  (1,
#   u'0.016*"go" + 0.015*"people" + 0.015*"get" + 0.012*"work" + 0.011*"know" + 0.011*"want" + 0.011*"say" + 0.009*"country" + 0.008*"america" + 0.008*"family"'),
#  (2,
#   u'0.027*"go" + 0.017*"people" + 0.015*"say" + 0.013*"country" + 0.012*"know" + 0.012*"get" + 0.009*"great" + 0.008*"want" + 0.007*"take" + 0.006*"happen"')]

# %%
# %%time

# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
print('\n')
# Out:
# ('\nPerplexity: ', -7.247581712417654)
# ('\nCoherence Score: ', 0.2843947702077843)
#
#
# CPU times: user 1.82 s, sys: 64.5 ms, total: 1.89 s
# Wall time: 6.74 s

# %%
# %%time

# Visualize the topics
#
# If you get an error like this: "pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. 
# A future version of pandas will change to not sort by default."
#
# then from the command line do: "pip install pandas==0.21.0"

pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)  # sort=False ? sort=True
vis
print('\n')
# Out:
# CPU times: user 1.03 s, sys: 113 ms, total: 1.15 s
# Wall time: 8.59 s
# /anaconda2/lib/python2.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))

# %% [markdown]
# #import pandas as pd
# #pd.__version__
#
# vis

# %%
vis
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 1      41.106239        1       1  0.082545  0.038340
# 2      29.525709        1       2  0.001906 -0.074141
# 0      29.368050        1       3 -0.084450  0.035801, topic_info=     Category         Freq        Term        Total  loglift  logprob
# term
# 3511  Default  2109.000000    american  2109.000000  30.0000  30.0000
# 793   Default  1906.000000         say  1906.000000  29.0000  29.0000
# 8747  Default  1775.000000        know  1775.000000  28.0000  28.0000
# 3860  Default  3747.000000          go  3747.000000  27.0000  27.0000
# 8644  Default  1434.000000         job  1434.000000  26.0000  26.0000
# 1574  Default   387.000000     clinton   387.000000  25.0000  25.0000
# 2681  Default   254.000000        isis   254.000000  24.0000  24.0000
# 2931  Default   561.000000      happen   561.000000  23.0000  23.0000
# 5151  Default   285.000000     african   285.000000  22.0000  22.0000
# 4785  Default   414.000000  government   414.000000  21.0000  21.0000
# 5234  Default   877.000000       think   877.000000  20.0000  20.0000
# 5321  Default  2126.000000         get  2126.000000  19.0000  19.0000
# 3379  Default   891.000000      family   891.000000  18.0000  18.0000
# 4212  Default   298.000000      policy   298.000000  17.0000  17.0000
# 1728  Default  1041.000000       great  1041.000000  16.0000  16.0000
# 8360  Default   177.000000        folk   177.000000  15.0000  15.0000
# 1255  Default   564.000000      really   564.000000  14.0000  14.0000
# 306   Default   224.000000        fail   224.000000  13.0000  13.0000
# 330   Default  2393.000000     country  2393.000000  12.0000  12.0000
# 3405  Default   246.000000     citizen   246.000000  11.0000  11.0000
# 360   Default   584.000000       child   584.000000  10.0000  10.0000
# 1405  Default   864.000000         see   864.000000   9.0000   9.0000
# 4720  Default   312.000000         bad   312.000000   8.0000   8.0000
# 4459  Default   672.000000         new   672.000000   7.0000   7.0000
# 5069  Default   105.000000         boo   105.000000   6.0000   6.0000
# 777   Default   431.000000      future   431.000000   5.0000   5.0000
# 4502  Default   672.000000        tell   672.000000   4.0000   4.0000
# 3923  Default   390.000000         win   390.000000   3.0000   3.0000
# 3109  Default   188.000000     rebuild   188.000000   2.0000   2.0000
# 5255  Default   201.000000     hillary   201.000000   1.0000   1.0000
# ...       ...          ...         ...          ...      ...      ...
# 7524   Topic3   126.653297       crime   184.555145   0.8488  -6.1458
# 1337   Topic3   219.589493        plan   364.445068   0.7186  -5.5955
# 4459   Topic3   356.106232         new   672.095215   0.5901  -5.1121
# 5926   Topic3    94.025513     foreign   131.238495   0.8918  -6.4437
# 5255   Topic3   129.793274     hillary   201.539246   0.7852  -6.1213
# 8343   Topic3   196.622482     include   351.702209   0.6438  -5.7060
# 330    Topic3   849.921631     country  2393.051270   0.1901  -4.2421
# 356    Topic3   214.626923      worker   410.066437   0.5778  -5.6184
# 8425   Topic3   241.888947         tax   485.444855   0.5287  -5.4988
# 475    Topic3   535.181213     america  1474.617188   0.2117  -4.7047
# 1445   Topic3   216.816879   community   428.355591   0.5444  -5.6082
# 777    Topic3   217.306015      future   431.254578   0.5399  -5.6060
